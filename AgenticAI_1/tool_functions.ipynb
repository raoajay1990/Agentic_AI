# %%
import requests
import os
from dotenv import load_dotenv

# %%
load_dotenv()
rapid_api_key = os.getenv('RAPID_API_KEY')
url = "https://cricket-api-free-data.p.rapidapi.com/cricket-schedule"

# %%
headers = {
    "x-rapidapi-key": rapid_api_key,
	"x-rapidapi-host": "cricket-api-free-data.p.rapidapi.com",
	"Content-Type": "application/json"
}

# %%
def get_fixtures():
    response = requests.get(url, headers = headers)
    print(response.json())

# %%
get_fixtures()
# Out:
# {'status': 'success', 'response': {'schedules': [{'scheduleAdWrapper': {'date': 'THU, JUN 18 2026', 'matchScheduleList': [{'seriesName': "Kwibuka Women's T20I Tournament, 2026", 'matchInfo': [{'matchId': 160119, 'seriesId': 12485, 'matchDesc': '11th Match', 'matchFormat': 'T20', 'startDate': '1781767800000', 'endDate': '1781827199000', 'team1': {'teamId': 720, 'teamName': 'Rwanda Women', 'teamSName': 'RWAW', 'imageId': 248448}, 'team2': {'teamId': 491, 'teamName': 'Brazil Women', 'teamSName': 'BRAW', 'imageId': 172539}, 'venueInfo': {'ground': 'Gahanga B Ground', 'city': 'Kigali City', 'country': 'Rwanda', 'timezone': '+02:00'}}], 'seriesId': 12485, 'seriesCategory': 'Women'}, {'seriesName': 'Malta Women tour of Cyprus, 2026', 'matchInfo': [{'matchId': 161701, 'seriesId': 12585, 'matchDesc': '1st T20I', 'matchFormat': 'T20', 'startDate': '1781767800000', 'endDate': '1781827199000', 'team1': {'teamId': 1992, 'teamName': 'Cyprus Women', 'teamSName': 'CYPW', 'imageId': 502582}, 'team2': {'teamId': 1500, 'teamName': 'Malta Women', 'teamSName': 'MALW', 'imageId': 297979}, 'venueInfo': {'ground': 'Kennington Oval', 'city': 'London', 'country': 'England', 'timezone': '+01:00'}}, {'matchId': 161711, 'seriesId': 12585, 'matchDesc': '2nd T20I', 'matchFormat': 'T20', 'startDate': '1781785800000', 'endDate': '1781827199000', 'team1': {'teamId': 1992, 'teamName': 'Cyprus Women', 'teamSName': 'CYPW', 'imageId': 502582}, 'team2': {'teamId': 1500, 'teamName': 'Malta Women', 'teamSName': 'MALW', 'imageId': 297979}, 'venueInfo': {'ground': 'Happy Valley Ground', 'city': 'Episkopi', 'country': 'Cyprus', 'timezone': '+03:00'}}], 'seriesId': 12585, 'seriesCategory': 'Women'}, {'seriesName': 'Madhya Pradesh Premier League 2026', 'matchInfo': [{'matchId': 160678, 'seriesId': 12530, 'matchDesc': '34th Match', 'matchFormat': 'T20', 'startDate': '1781775000000', 'endDate': '1781827199000', 'team1': {'teamId': 3417, 'teamName': 'Ujjain Falcons', 'teamSName': 'UFS', 'imageId': 1003332}, 'team2': {'teamId': 2490, 'teamName': 'Indore Pink Panthers', 'teamSName': 'IPP', 'imageId': 715355}, 'venueInfo': {'ground': 'Holkar Stadium', 'city': 'Indore', 'country': 'India', 'timezone': '+05:30'}}, {'matchId': 160689, 'seriesId': 12530, 'matchDesc': '35th Match', 'matchFormat': 'T20', 'startDate': '1781791200000', 'endDate': '1781827199000', 'team1': {'teamId': 2457, 'teamName': 'Jabalpur Royal Lions', 'teamSName': 'JRL', 'imageId': 715351}, 'team2': {'teamId': 3413, 'teamName': 'Royal Nimar Eagles', 'teamSName': 'RNE', 'imageId': 1003334}, 'venueInfo': {'ground': 'Holkar Stadium', 'city': 'Indore', 'country': 'India', 'timezone': '+05:30'}}], 'seriesId': 12530, 'seriesCategory': 'League'}, {'seriesName': 'New Zealand tour of England, 2026', 'matchInfo': [{'matchId': 129563, 'seriesId': 10559, 'matchDesc': '2nd Test, Day 2', 'matchFormat': 'TEST', 'startDate': '1781776800000', 'endDate': '1782086399000', 'team1': {'teamId': 9, 'teamName': 'England', 'teamSName': 'ENG', 'isFullMember': True, 'imageId': 776237}, 'team2': {'teamId': 13, 'teamName': 'New Zealand', 'teamSName': 'NZ', 'isFullMember': True, 'imageId': 776333}, 'venueInfo': {'ground': 'Kennington Oval', 'city': 'London', 'country': 'England', 'timezone': '+01:00'}}], 'seriesId': 10559, 'seriesCategory': 'International'}, {'seriesName': 'Namibia T20I Tri-Series 2026', 'matchInfo': [{'matchId': 161564, 'seriesId': 12569, 'matchDesc': '1st Match', 'matchFormat': 'T20', 'startDate': '1781784000000', 'endDate': '1781827199000', 'team1': {'teamId': 8, 'teamName': 'Hong Kong, China', 'teamSName': 'HKC', 'imageId': 776271}, 'team2': {'teamId': 536, 'teamName': 'Nigeria', 'teamSName': 'NGA', 'imageId': 248436}, 'venueInfo': {'ground': 'Namibia Cricket Ground', 'city': ' Windhoek', 'country': 'Namibia', 'timezone': '+02:00'}}], 'seriesId': 12569, 'seriesCategory': 'International'}, {'seriesName': 'Germany tour of Denmark, 2026', 'matchInfo': [{'matchId': 160215, 'seriesId': 12510, 'matchDesc': '1st T20I', 'matchFor ...
